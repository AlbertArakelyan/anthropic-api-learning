# %%
# Install dependencies
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (0.104.0)
# Requirement already satisfied: python-dotenv in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from anthropic) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from anthropic) (0.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: sniffio in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from anyio<5,>=3.5.0->anthropic) (3.16)
# Requirement already satisfied: certifi in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from httpx<1,>=0.25.0->anthropic) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Load env variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create an API client
from anthropic import Anthropic

client = Anthropic()

model = "claude-sonnet-4-6"

# %%
def add_user_message(messages, text):
  user_message = {"role": "user", "content": text}
  messages.append(user_message)

def add_assistant_message(messages, text):
  assistant_message = {"role": "assistant", "content": text}
  messages.append(assistant_message)

def chat(messages):
  message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=messages,
  )

  return message.content[0].text

# %%
# THIS EXERCISE LIVES IN A SEPARATE FILE `3_5_chat-bot-exxercise.ipynb.ipynb`

# Make an initial list of messages
messages = []

# Use a 'while True' loop to run the chatbot forever
while True:
  # Get user input
  user_input = input("> ")
  print(">", user_input)

  # Add user input to the list of messages
  add_user_message(messages, user_input)
  
  # Call Claude with the 'chat' function
  answer = chat(messages)
  
  # Add generated text to the list of messages
  add_assistant_message(messages, answer)
  
  # Print the generated text
  print("---")
  print(answer)
  print("---")
