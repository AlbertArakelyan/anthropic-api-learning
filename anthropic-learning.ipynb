# %%
# Install dependencies
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (0.104.0)
# Requirement already satisfied: python-dotenv in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from anthropic) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from anthropic) (0.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: sniffio in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from anyio<5,>=3.5.0->anthropic) (3.16)
# Requirement already satisfied: certifi in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from httpx<1,>=0.25.0->anthropic) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\alber\desktop\jupyter-notebooks\anthropic-api-learning\venv\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Load env variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create an API client
from anthropic import Anthropic

client = Anthropic()

model = "claude-sonnet-4-6"

# %%
def add_user_message(messages, text):
  user_message = {"role": "user", "content": text}
  messages.append(user_message)

def add_assistant_message(messages, text):
  assistant_message = {"role": "assistant", "content": text}
  messages.append(assistant_message)

def chat(messages):
  message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=messages,
  )

  return message.content[0].text

# %%
# Make a starting list of messages
messages = []

# Add in the initial user question of "Define quantum computing in one sentence"
add_user_message(messages, "Define quantum computing in one sentence")

# Pass the list of messages into into 'chat' to get an answer
answer = chat(messages)

# Take the answer and add it as an assistant message into our list
add_assistant_message(messages, answer)

# Add in the user's follow-up question
add_user_message(messages, "Write another sentence")

# Call chat again with the list of messages to get a final answer
answer = chat(messages)
answer
# Out:
# 'Unlike classical computers, which store information as binary bits (0s and 1s), quantum computers use **qubits** that can exist in multiple states simultaneously, enabling them to explore many possible solutions to a problem at the same time.'

# %%
# THIS EXERCISE LIVES IN A SEPARATE FILE `3_5_chat-bot-exercise.ipynb`

# Make an initial list of messages
messages = []

# Use a 'while True' loop to run the chatbot forever
while True:
  # Get user input
  user_input = input("> ")
  print(">", user_input)

  # Add user input to the list of messages
  add_user_message(messages, user_input)
  
  # Call Claude with the 'chat' function
  answer = chat(messages)
  
  # Add generated text to the list of messages
  add_assistant_message(messages, answer)
  
  # Print the generated text
  print("---")
  print(answer)
  print("---")
# Out:
# > test test :D
# ---
# Hello! 👋 😄
#
# It looks like you're just testing things out — that's totally fine! Everything seems to be working.
#
# Is there something I can help you with today?
# ---
# > why linux is so amazing, and windows draining?
# ---
# # Why Linux is Amazing & Windows Can Be Draining 🐧 vs 🪟
#
# ## Linux - Why It's Great ✅
#
# ### 🔓 Freedom & Control
# - **Open source** - you can see and modify the code
# - You **own** your system completely
# - No forced updates or restrictions
#
# ### ⚡ Performance
# - **Lightweight** - runs fast even on old hardware
# - No bloatware or unnecessary background processes
# - Better RAM and CPU management
#
# ### 🔒 Security & Privacy
# - Much **harder to get viruses**
# - No telemetry spying on you
# - You control what runs on your system
#
# ### 🛠️ Customization
# - Change **everything** about your system
# - Hundreds of different distros for different needs
# - Make it look and work exactly how YOU want
#
# ---
#
# ## Windows - Why It Can Feel Draining 😩
#
# - **Forced updates** at the worst times
# - **Bloatware** pre-installed
# - Heavy on resources
# - **Telemetry** collecting your data
# - Constant ads even in the Start Menu
# - Expensive licenses
# - Slows down over time
#
# ---
#
# ## Bottom Line 💡
# > Linux gives you a system that **works for you**
# > Windows sometimes feels like it works **against you**
#
# Are you thinking about switching to Linux? 😄
# ---
# > I did already switch dude ;)
# ---
# # That's Awesome!! 🎉🐧
#
# ### Welcome to the Linux Master Race! 😄
#
# So you already made the jump! That's great!
#
# ## Quick Questions:
# - **Which distro** are you running?
#   - Ubuntu? 🟠
#   - Arch? btw 😏
#   - Fedora? 🔵
#   - Something else?
#
# ---
#
# ## How's the Experience So Far? 😄
#
# - Getting used to the terminal? 💻
# - Everything working smoothly?
# - Any hardware issues?
#
# ---
#
# ### The Feeling of Being Free From Windows is REAL 😂
# - No random updates rebooting your PC
# - No "Just a moment..." screens 😆
# - No ads in your Start Menu
# - Your PC actually feels like **YOUR PC**
#
# ---
#
# > **Once you go Linux, you never go back!** 🐧❤️
#
# So tell me more about your setup! What made you finally switch? 😄
# ---
# >
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[8], line 14
#      10   # Add user input to the list of messages
#      11   add_user_message(messages, user_input)
#      12
#      13   # Call Claude with the 'chat' function
# ---> 14   answer = chat(messages)
#      15
#      16   # Add generated text to the list of messages
#      17   add_assistant_message(messages, answer)
#
# Cell In[5], line 10, in chat(messages)
#       9 def chat(messages):
# ---> 10   message = client.messages.create(
#      11     model=model,
#      12     max_tokens=1000,
#      13     messages=messages,
#
# File c:\Users\alber\Desktop\jupyter-notebooks\anthropic-api-learning\venv\Lib\site-packages\anthropic\_utils\_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File c:\Users\alber\Desktop\jupyter-notebooks\anthropic-api-learning\venv\Lib\site-packages\anthropic\resources\messages\messages.py:1003, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     996 if model in MODELS_TO_WARN_WITH_THINKING_ENABLED and thinking and thinking["type"] == "enabled":
#     997     warnings.warn(
#     998         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#     999         UserWarning,
#    1000         stacklevel=3,
#    1001     )
# -> 1003 return self._post(
#    1004     "/v1/messages",
#    1005     body=maybe_transform(
#    1006         {
#    1007             "max_tokens": max_tokens,
#    1008             "messages": messages,
#    1009             "model": model,
#    1010             "cache_control": cache_control,
#    1011             "container": container,
#    1012             "inference_geo": inference_geo,
#    1013             "metadata": metadata,
#    1014             "output_config": output_config,
#    1015             "service_tier": service_tier,
#    1016             "stop_sequences": stop_sequences,
#    1017             "stream": stream,
#    1018             "system": system,
#    1019             "temperature": temperature,
#    1020             "thinking": thinking,
#    1021             "tool_choice": tool_choice,
#    1022             "tools": tools,
#    1023             "top_k": top_k,
#    1024             "top_p": top_p,
#    1025         },
#    1026         message_create_params.MessageCreateParamsStreaming
#    1027         if stream
#    1028         else message_create_params.MessageCreateParamsNonStreaming,
#    1029     ),
#    1030     options=make_request_options(
#    1031         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1032     ),
#    1033     cast_to=Message,
#    1034     stream=stream or False,
#    1035     stream_cls=Stream[RawMessageStreamEvent],
#    1036 )
#
# File c:\Users\alber\Desktop\jupyter-notebooks\anthropic-api-learning\venv\Lib\site-packages\anthropic\_base_client.py:1374, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1365     warnings.warn(
#    1366         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1367         "Please pass raw bytes via the `content` parameter instead.",
#    1368         DeprecationWarning,
#    1369         stacklevel=2,
#    1370     )
#    1371 opts = FinalRequestOptions.construct(
#    1372     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1373 )
# -> 1374 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\alber\Desktop\jupyter-notebooks\anthropic-api-learning\venv\Lib\site-packages\anthropic\_base_client.py:1147, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1144             err.response.read()
#    1146         log.debug("Re-raising status error")
# -> 1147         raise self._make_status_error_from_response(err.response) from None
#    1149     break
#    1151 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.6: user messages must have non-empty content'}, 'request_id': 'req_011CbPRM7BkQf9mrcHHxQa9T'}
